# %%
#import the libraries
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings("ignore")
import re

#import sklearn libraries
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from scipy.stats import randint
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,roc_auc_score, roc_curve

# %%
#load and read the dataset
df = pd.read_csv("Terry_Stops_20250909.csv")

#check the first five rows of the dataset
df.head()
# Out:
#   Subject Age Group   Subject ID     GO / SC Num  Terry Stop ID  \
# 0           26 - 35           -1  20170000036835         234548
# 1           46 - 55           -1  20180000275629         481899
# 2           36 - 45  49326761681  20230000118635    49327076666
# 3           36 - 45  53986235598  20240000029589    53986202139
# 4           18 - 25           -1  20150000002928          54115
#
#   Stop Resolution                        Weapon Type Officer ID  Officer YOB  \
# 0  Offense Report                               None       4852         1953
# 1   Field Contact                               None       8544         1993
# 2   Field Contact  Knife/Cutting/Stabbing Instrument       7766         1984
# 3   Field Contact                                  -       8723         1994
# 4   Field Contact                               None       7745         1988
#
#   Officer Gender        Officer Race  ...     Reported Time  \
# 0           Male               Asian  ...  18:36:00.0000000
# 1         Female            Hispanic  ...  13:47:00.0000000
# 2           Male               White  ...  07:25:58.0000000
# 3           Male               White  ...  02:50:52.0000000
# 4         Female  Declined to Answer  ...  00:22:00.0000000
#
#                             Initial Call Type  \
# 0                                 DISTURBANCE
# 1                                           -
# 2          OBS - DOWN - CHECK FOR PERSON DOWN
# 3  SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 4                                           -
#
#                           Final Call Type Call Type  \
# 0                        THEFT - SHOPLIFT       911
# 1                                       -         -
# 2  SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON    ONVIEW
# 3                     DISTURBANCE - OTHER    ONVIEW
# 4                                       -         -
#
#                                 Officer Squad Arrest Flag Frisk Flag Precinct  \
# 0       NORTH PCT 2ND W - LINCOLN - PLATOON 1           N          N    North
# 1            NORTH PCT 2ND WATCH - B/N RELIEF           N          N     West
# 2  WEST PCT 1ST W - QUEEN (DAVID) - PLATOON 1           N          Y     West
# 3           WEST PCT 3RD W - KING - PLATOON 1           N          N     West
# 4           SOUTH PCT 3RD W - SAM - PLATOON 2           N          N        -
#
#   Sector Beat
# 0      L   L3
# 1      Q   Q2
# 2      K   K3
# 3      D   D2
# 4      -    -
#
# [5 rows x 23 columns]

# %%
#check the last rows of the dataset
df.tail()
# Out:
#       Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 64732           18 - 25          -1  20170000325937         354197
# 64733           26 - 35          -1  20190000122094         549491
# 64734           36 - 45          -1  20180000467077         512455
# 64735           26 - 35          -1  20190000059044         532813
# 64736           18 - 25          -1  20180000001424         412377
#
#       Stop Resolution Weapon Type Officer ID  Officer YOB Officer Gender  \
# 64732  Offense Report        None       7755         1971           Male
# 64733          Arrest        None       7489         1985         Female
# 64734          Arrest        None       7758         1987           Male
# 64735  Offense Report        None       7649         1986           Male
# 64736   Field Contact        None       8558         1993           Male
#
#       Officer Race  ...     Reported Time  \
# 64732        White  ...  22:58:00.0000000
# 64733        White  ...  13:01:00.0000000
# 64734        White  ...  04:35:00.0000000
# 64735        White  ...  14:35:00.0000000
# 64736        White  ...  14:10:00.0000000
#
#                                        Initial Call Type  \
# 64732                                                  -
# 64733         SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 64734  OBS - BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)
# 64735                     ASLT - CRITICAL (NO SHOOTINGS)
# 64736                                                  -
#
#                  Final Call Type Call Type  \
# 64732                          -         -
# 64733  WARRANT SERVICES - FELONY    ONVIEW
# 64734    NARCOTICS - NARS REPORT       911
# 64735            ASSAULTS, OTHER       911
# 64736                          -         -
#
#                                Officer Squad Arrest Flag Frisk Flag Precinct  \
# 64732      WEST PCT 3RD W - KING - PLATOON 1           N          N     West
# 64733                NORTH PCT OPS - ACT DAY           N          N    North
# 64734  EAST PCT 1ST W - E/G RELIEF (CHARLIE)           N          N     East
# 64735           SOUTH PCT 2ND W - R/S RELIEF           N          N    South
# 64736        TRAINING - FIELD TRAINING SQUAD           N          N        -
#
#       Sector Beat
# 64732      M   M2
# 64733      N   N3
# 64734      E   E1
# 64735      S   S1
# 64736      -    -
#
# [5 rows x 23 columns]

# %%
#check the shape of the dataset
df.shape
# Out:
# (64737, 23)

# %%
#check the data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64737 entries, 0 to 64736
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject Age Group         64737 non-null  object
#  1   Subject ID                64737 non-null  int64
#  2   GO / SC Num               64737 non-null  int64
#  3   Terry Stop ID             64737 non-null  int64
#  4   Stop Resolution           64737 non-null  object
#  5   Weapon Type               64737 non-null  object
#  6   Officer ID                64737 non-null  object
#  7   Officer YOB               64737 non-null  int64
#  8   Officer Gender            64737 non-null  object
#  9   Officer Race              64737 non-null  object
#  10  Subject Perceived Race    64737 non-null  object
#  11  Subject Perceived Gender  64737 non-null  object
#  12  Reported Date             64737 non-null  object
#  13  Reported Time             64737 non-null  object
#  14  Initial Call Type         64737 non-null  object
#  15  Final Call Type           64737 non-null  object
#  16  Call Type                 64737 non-null  object
#  17  Officer Squad             64168 non-null  object
#  18  Arrest Flag               64737 non-null  object
#  19  Frisk Flag                64737 non-null  object
#  20  Precinct                  64737 non-null  object
#  21  Sector                    64737 non-null  object
#  22  Beat                      64737 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 11.4+ MB

# %%
#check statistical summary for numerical columns
df.describe()
# Out:
#          Subject ID   GO / SC Num  Terry Stop ID   Officer YOB
# count  6.473700e+04  6.473700e+04   6.473700e+04  64737.000000
# mean   8.993283e+09  2.019008e+13   1.507724e+10   1984.467090
# std    1.538334e+10  8.439261e+10   2.069983e+10      9.189523
# min   -8.000000e+00 -1.000000e+00   2.802000e+04   1900.000000
# 25%   -1.000000e+00  2.017000e+13   2.547370e+05   1980.000000
# 50%   -1.000000e+00  2.019000e+13   5.347130e+05   1986.000000
# 75%    7.803391e+09  2.021000e+13   2.667422e+10   1991.000000
# max    6.581126e+10  2.025000e+13   6.581120e+10   2003.000000

# %%
#check statistical summary for categorical columns
df.describe(include="object").T
# Out:
#                           count unique                              top   freq
# Subject Age Group         64737      7                          26 - 35  21576
# Stop Resolution           64737      5                    Field Contact  32234
# Weapon Type               64737     23                             None  32565
# Officer ID                64737   1435                             7456    551
# Officer Gender            64737      3                             Male  57366
# Officer Race              64737      9                            White  46063
# Subject Perceived Race    64737     11                            White  31649
# Subject Perceived Gender  64737      7                             Male  51093
# Reported Date             64737   3829              2015-10-01T00:00:00    101
# Reported Time             64737  26254                 03:09:00.0000000     52
# Initial Call Type         64737    186                                -  13602
# Final Call Type           64737    203                                -  13602
# Call Type                 64737      8                              911  30545
# Officer Squad             64168    277  TRAINING - FIELD TRAINING SQUAD   6998
# Arrest Flag               64737      2                                N  57400
# Frisk Flag                64737      3                                N  48527
# Precinct                  64737      9                             West  18416
# Sector                    64737     20                                -  10973
# Beat                      64737     55                                -  10967

# %%
#check unique values
for coln in df:
    uni_value = df[coln].unique()
    print(f" {coln}\n, {uni_value}\n")
# Out:
#  Subject Age Group
# , ['26 - 35' '46 - 55' '36 - 45' '18 - 25' '-' '56 and Above' '1 - 17']
#
#  Subject ID
# , [         -1 49326761681 53986235598 ... 12282720243 15947861935
#   7751138304]
#
#  GO / SC Num
# , [20170000036835 20180000275629 20230000118635 ... 20180000467077
#  20190000059044 20180000001424]
#
#  Terry Stop ID
# , [     234548      481899 49327076666 ...      512455      532813
#       412377]
#
#  Stop Resolution
# , ['Offense Report' 'Field Contact' 'Arrest' 'Referred for Prosecution'
#  'Citation / Infraction']
#
#  Weapon Type
# , ['None' 'Knife/Cutting/Stabbing Instrument' '-'
#  'Lethal Cutting Instrument' 'Handgun' 'Blunt Object/Striking Implement'
#  'Firearm' 'Mace/Pepper Spray' 'Club' 'Club, Blackjack, Brass Knuckles'
#  'Firearm Other' 'Fire/Incendiary Device' 'Firearm (unk type)'
#  'None/Not Applicable' 'Other Firearm' 'Taser/Stun Gun'
#  'Automatic Handgun' 'Shotgun' 'Rifle' 'Poison'
#  'Personal Weapons (hands, feet, etc.)' 'Blackjack' 'Brass Knuckles']
#
#  Officer ID
# , ['4852' '8544' '7766' ... '5797' '8952' '5029']
#
#  Officer YOB
# , [1953 1993 1984 1994 1988 1981 1990 1976 1985 1959 1992 1989 1987 1983
#  1977 1996 1971 1997 1973 1991 1986 1978 1964 1967 1982 1979 1970 1980
#  1969 1999 1995 1975 1968 1960 1962 1961 1998 2002 1974 1966 1965 1900
#  1972 2000 1963 2001 1956 1954 1957 1948 1949 1958 1955 1946 2003 1952
#  1951]
#
#  Officer Gender
# , ['Male' 'Female' 'Non-Specified']
#
#  Officer Race
# , ['Asian' 'Hispanic' 'White' 'Declined to Answer'
#  'Black or African American' 'Two or More Races'
#  'Native Hawaiian or Other Pacific Islander'
#  'American Indian or Alaska Native' 'Unknown']
#
#  Subject Perceived Race
# , ['White' 'Native Hawaiian or Other Pacific Islander'
#  'Black or African American' 'Hispanic' 'American Indian or Alaska Native'
#  'Asian' 'Multi-Racial' '-' 'Unknown' 'Other' 'MULTIPLE SUBJECTS']
#
#  Subject Perceived Gender
# , ['Male' 'Female' 'Unable to Determine' '-' 'Unknown'
#  'Gender Diverse (gender non-conforming and/or transgender)'
#  'MULTIPLE SUBJECTS']
#
#  Reported Date
# , ['2017-01-30T00:00:00' '2018-07-30T00:00:00' '2023-05-02T00:00:00' ...
#  '2024-06-29T00:00:00' '2015-04-16T00:00:00' '2015-05-11T00:00:00']
#
#  Reported Time
# , ['18:36:00.0000000' '13:47:00.0000000' '07:25:58.0000000' ...
#  '16:50:24.0000000' '07:28:53.0000000' '22:47:07.0000000']
#
#  Initial Call Type
# , ['DISTURBANCE' '-' 'OBS - DOWN - CHECK FOR PERSON DOWN'
#  'SUSPICIOUS STOP - OFFICER INITIATED ONVIEW'
#  'OBS WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)'
#  'ASLT - WITH OR W/O WPNS (NO SHOOTINGS)' 'TRESPASS'
#  'BURG - RESD (INCL UNOCC STRUCTURES ON PROP)'
#  'SUSPICIOUS PERSON, VEHICLE, OR INCIDENT'
#  'OBS - FIGHT - IP - PHYSICAL (NO WEAPONS)' 'SHOPLIFT - THEFT'
#  'ROBBERY - CRITICAL (INCLUDES STRONG ARM)'
#  'TRAFFIC STOP - OFFICER INITIATED ONVIEW' 'DISTURBANCE - DV CRITICAL'
#  'UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)'
#  'NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)'
#  'THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)' 'WARRANT - FELONY PICKUP'
#  'ASLT - PERSON SHOT OR SHOT AT' 'BURG - OCCUPIED RESD'
#  'ASLT - CRITICAL (NO SHOOTINGS)' 'FIGHT - CRITICAL WITH WEAPONS'
#  'WARRANT - SEARCH. CAUTION (EXCL NARCOTICS)' 'AUTO RECOVERY'
#  'SERVICE - WELFARE CHECK' 'PROPERTY - DAMAGE'
#  'THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)'
#  'HARAS - NO BIAS OR THREATS' 'BURN - RECKLESS BURNING'
#  'ASLT - DV CRITICAL' 'OBS - PROWLER - IP/JO' 'ROBBERY (INCL STRONG ARM)'
#  'SEX IN PUBLIC PLACE (INCL MASTURBATION)'
#  'PERSON IN BEHAVIORAL/EMOTIONAL CRISIS'
#  'WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)' 'WARRANT - MISD PICKUP'
#  'DIRECTED PATROL ACTIVITY' 'TRAFFIC - BLOCKING ROADWAY'
#  'PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY'
#  'ALARM - COMM, SILENT/AUD BURG (INCL BANKS)'
#  'DUI - DRIVING UNDER INFLUENCE' 'NUISANCE'
#  'ASSIST OTHER AGENCY - EMERGENCY SERVICE' 'NARCOTICS - FOUND'
#  'UNDERCOVER OPS, CAUTION (INCLUDES STAKEOUTS)'
#  'ORDER - VIOLATING DV COURT ORDER'
#  'UNKNOWN - COMPLAINT OF UNKNOWN NATURE' 'FRAUD'
#  'OBS - FIGHT - VERBAL/ORAL (NO WEAPONS)' 'BURG - COMM BURGLARY'
#  'DISTURBANCE - DV - NO ASLT' 'THREATS - DV - NO ASSAULT'
#  'LEWD -  (EXPOSING, FLASHING)'
#  'OBS - BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)'
#  'PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)'
#  'CHILD - ABAND, ABUSE, MOLEST, NEGLECT'
#  'OBS - REPORT, NON INJ/NON BLKG OR AFTER FACT INJ'
#  'JUVENILE - RUNAWAY PICKUP' 'HELP THE OFFICER'
#  'AUTO THEFT - VEH THEFT OR THEFT AND RECOVERY'
#  'ASSIST PUBLIC - NO WELFARE CHK OR DV ORDER SERVICE'
#  'FIGHT - PHYSICAL (NO WEAPONS)' 'DOWN - CHECK FOR DOWN PERSON'
#  'MVC - HIT AND RUN' 'ASSIST SPD'
#  'OBS - MVC - WITH INJURIES (INCLUDES HIT AND RUN)'
#  'ANIMAL - INJURED, DEAD HAZARD, OTHER' 'OPEN - BUILDING, DOOR, ETC.'
#  'ASSIST OTHER AGENCY - ROUTINE SERVICE' 'THEFT OF SERVICES'
#  'OBS - EXPLOSION - IP/JO' 'OBS - ARSON - IP/JO'
#  'LIQUOR VIOLATIONS - ADULT' 'WARRANT - SEARCH. EXECUTED, SECURED'
#  'SFD - ASSIST ON CRITICAL FIRE OR MEDIC RESPONSE'
#  'HAZ - POTENTIAL THRT TO PHYS SAFETY' 'LIQUOR VIOLATIONS - MINOR'
#  'OBS - MVC - NON INJURY, BLOCKING' 'ASLT - DV' 'OBS - MVC - UNK INJURIES'
#  'RAPE' 'OVERDOSE' 'SHOTS HEARD - IN PROGRESS' 'ABDUCTION - CRITICAL'
#  'VICE - PROSTITUTION' 'SUICIDE - CRITICAL' 'PEDESTRIAN VIOLATIONS'
#  'NARCOTICS WARRANT SERVICE'
#  'ASLT - MOLESTED ADULT (GROPED, FONDLED, ETC.)'
#  'UNKNOWN - ANI/ALI - LANDLINE (INCLUDES OPEN LINE)'
#  'OBS - NOISE - DISTURBANCE (PARTY, ETC)' 'MVC - COLLISION (ALL)'
#  'PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)' 'FOLLOW UP'
#  'ORDER - CRITICAL VIOLATION OF DV COURT ORDER'
#  'OBS - ANIMAL - IP/JO - BITE'
#  'ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)' 'TRAFFIC - ROAD RAGE'
#  'OBS - AUTO THEFT-IP/JO - VEHICLE, PLATES, TABS' 'ILLEGAL DUMPING'
#  'FOOT - ELUDING POLICE' 'ALARM - TRACKING ALARM'
#  'CHILD - CRITICAL ABAND, ABUSE, MOLEST, NEGLECT'
#  'ALARM - AUDIBLE AUTOMOBILE (UNOCC/ANTI-THEFT)'
#  'OBS - SUSPICIOUS PACKAGE' 'SHOTS HEARD - DELAY' 'FIGHT - WITH WEAPONS'
#  'SFD - ASSIST ON FIRE OR MEDIC RESPONSE' 'AUTO - THEFT/LOSS OF PLATES'
#  'ASLT - REPORT FOR PERSON SHOT OR SHOT AT' 'BOMB THREATS - CRITICAL'
#  'TRAF - ELUDING POLICE' 'FIREWORKS (NO HAZARD)'
#  'CARJACKING - IP/JO - ROBBERY' 'AWOL - ADULT OR JUVENILE' 'BIAS'
#  'ALARM - BANK (HOLD-UP)' 'TRAFFIC - MOVING VIOLATION' 'FOUND PERSON'
#  'PANHANDLING, AGGRESSIVE' 'MISSING - CHILD'
#  'PROPERTY - DAMAGE (GUN RELATED)' 'OBS - PURSE SNATCH - ROBBERY'
#  'ORDER - VIOLATION OF COURT ORDER (NON DV)' 'JUVENILE - RUNAWAY'
#  'SUICIDE - SUICIDAL PERSON AND ATTEMPTS' 'HAZ - CRITICAL'
#  'ALARM - RESIDENTIAL - BURGLARY, SILENT/AUDIBLE' 'OBS - PROWLER'
#  'OBS - INJURED - IP/JO - PERSON/INDUSTRIAL ACCIDENT'
#  'OBS - PURSE SNATCH - IP/JO - ROBBERY' 'PROPERTY - FOUND'
#  'LICENSE INSPECTIONS (CHECK FOR)' 'OBS - ASSIST SPD - URGENT SERVICE'
#  'ARSON - REPORT' 'TRU - THEFT' 'NOISE - GENERAL' 'OBS - RAPE - IP/JO'
#  'PARKING VIOLATION (EXCEPT ABANDONED CAR)'
#  'NARCOTICS WARRANT SERVICE - EXECUTED, SECURED'
#  'OBS - SLEEPER ABOARD BUS/COMMUTER TRAIN'
#  'WARRANT PICKUP - FROM OTHER AGENCY' 'REQUEST TO WATCH'
#  'CARJACKING - ROBBERY' 'MISSING - (ALZHEIMER, ENDANGERED, ELDERLY)'
#  'ALARM - COMM, HOLD-UP/PANIC (EXCEPT BANKS)'
#  'ABDUCTION - NO KNOWN KIDNAPPING' 'ASSIGNED DUTY - STAKEOUT'
#  'ALARM - RESIDENTIAL - SILENT/AUD PANIC/DURESS'
#  'OBS - DOA - CASUALTY, DEAD BODY' 'OBS - SICK PERSON'
#  'TRAFFIC - ASSIST MOTORIST' 'URINATING, DEFECATING IN PUBLIC'
#  'CUSTODIAL INTERFERENCE - DV' 'ASSIGNED DUTY - DETAIL BY SUPERVISOR'
#  'CHILD - IP/JO - LURING' 'OFF DUTY EMPLOYMENT' 'CHILD -  LURING'
#  'PUBLIC DISPLAY OF PORNOGRAPHY' 'SEX OFFENDER - FAILURE TO REGISTER'
#  'ALARM - PUBLIC TRANSPORTATION (CITY/STATE/COUNTY)'
#  'ORDER  - SERVICE OF DV COURT ORDER' 'LITTERING' 'MISSING - ADULT'
#  'ANIMAL BITE' 'DOA - CASUALTY, DEAD BODY' 'TRU - AUTO THEFT'
#  'OBS - UNKNOWN - ANI/ALI - PAY PHN (INCL OPEN LINE)' 'GAMBLING'
#  'ALARM - ATM MACHINE, FREE STANDING' 'KNOWN KIDNAPPNG'
#  'ESCAPE - PRISONER' 'PROPERTY - FOUND GUN, SHELLCASINGS'
#  'PREPLANNED EVENT' 'BOMB - THREATS'
#  'PHONE - OBSCENE OR NUISANCE PHONE CALLS'
#  'INJURED -  PERSON/INDUSTRIAL ACCIDENT' 'ABANDONED VEHICLE'
#  'ALARM - DURESS/PANIC,TAXI/CAR/PRSN - NOT DV'
#  'HARBOR - WATER EMERGENCIES'
#  'ORDER - ASSIST DV VIC W/SRVC OF COURT ORDER' 'EXPLOSION'
#  'STADIUM EVENT ASSIGNMENT' 'DEMONSTRATIONS' 'INFORMATIONAL BROADCASTS'
#  'ANIMAL - DANGEROUS']
#
#  Final Call Type
# , ['THEFT - SHOPLIFT' '-' 'SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON'
#  'DISTURBANCE - OTHER' 'WARRANT SERVICES - MISDEMEANOR' 'ASSAULTS, OTHER'
#  'PROWLER - TRESPASS' 'BURGLARY - RESIDENTIAL OCCUPIED'
#  'WARRANT SERVICES - FELONY' 'NARCOTICS - DRUG TRAFFIC LOITERING'
#  'ROBBERY - ARMED' 'NARCOTICS - OTHER' 'WEAPON, PERSON WITH - GUN'
#  'DV - DOMESTIC VIOL/ASLT (ARREST MANDATORY)' 'TRAFFIC - MOVING VIOLATION'
#  'CRISIS COMPLAINT - GENERAL' 'PROWLER - GENERAL'
#  'AUTOMOBILES - AUTO THEFT & RECOVERY'
#  'SUSPICIOUS CIRCUM. - SUSPICIOUS VEHICLE'
#  'DRIVE BY SHOOTING - NO INJURIES' 'ASSIST OTHER AGENCY - FEDERAL AGENCY'
#  'ROBBERY - STRONG ARM' 'PROPERTY DEST (DAMG) - GRAFFITI (INCLUDES GANG)'
#  'ASSAULTS - HARASSMENT, THREATS' 'AUTOMOBILES - RECOVERY (THEFT)'
#  'THEFT - ALL OTHER' 'THEFT - CAR PROWL'
#  'DV - DOMESTIC VIOLENCE (ARREST DISCRETIONARY)'
#  'ASSIST PUBLIC - 911 HANG UP, OPEN LINE' 'PROPERTY - MISSING PROPERTY'
#  'PROPERTY DEST (DAMG)' 'SEX OFFENSES (NON-RAPE) - LEWD CONDUCT'
#  'NARCOTICS - NARS REPORT' 'CHILD - ABANDONED, ABUSED AND NEGLECTED'
#  'TRAFFIC - D.U.I.' 'DV - ARGUMENTS, DISTURBANCE (NO ARREST)'
#  'WEAPON,PERSON WITH - OTHER WEAPON' 'TRAFFIC - REFUSE TO STOP (PURSUIT)'
#  'PREMISE CHECKS - CRIME PREVENTION' 'THEFT - BICYCLE' 'HOMICIDE'
#  'ALARM-COMM (INC BANK, ATM, SCHOOLS, BSN)'
#  'NARCOTICS - MARIJUANA PUBLIC USE(NOT DISPENSARY)'
#  'AUTOMOBILES - AUTO THEFT' 'ASSAULTS - FIREARM INVOLVED'
#  'ASSIST OTHER AGENCY - STATE AGENCY'
#  'DV - ENFORCE COURT ORDER (ARREST MANDATED)'
#  'FRAUD - FORGERY, BAD CHECKS' 'BURN - RECKLESS BURNING'
#  'BURGLARY - NON RESIDENTIAL/COMMERCIAL'
#  'BURGLARY - UNOCC STRUC ON RESN PROP' 'DISTURBANCE - NOISE'
#  'BURGLARY - RESIDENTIAL, UNOCCUPIED' 'DISTURBANCE - FIGHT'
#  'MISC MISD AND VIOLS - RECKLESS ENDANGERMENT' 'SHOPLIFT - THEFT'
#  'INTOX & LIQ VIOLS - INTOXICATED PERSON' 'VICE - PROSTITUTION'
#  'ASSIST OTHER AGENCY - COUNTY AGENCY'
#  'ASSIST PUBLIC - OTHER (NON-SPECIFIED)' 'THEFT - AUTO ACCESSORIES'
#  'ROBBERY - CRITICAL (INCLUDES STRONG ARM)'
#  'TRAFFIC - MV COLLISION INVESTIGATION'
#  'SUSPICIOUS PERSON, VEHICLE, OR INCIDENT' 'DISTURBANCE - JUVENILE'
#  'ANIMAL COMPLAINT - INJURED,DEAD,DANGEROUS' 'THEFT OF SERVICES'
#  'THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)'
#  'ARSON, BOMBS, EXPLO - RECKLESS BURNING'
#  'INTOX & LIQ VIOLS - ADULTS (VIOLATIONS)' 'DV - STANDBY TO ASSURE PEACE'
#  'MISCHIEF OR NUISANCE - GENERAL'
#  'INTOX & LIQ VIOLS - MINORS (VIOLATIONS)'
#  'AUTOMOBILES - LICENSE PLATE(S) THEFT OR LOSS' 'DIRECTED PATROL ACTIVITY'
#  'RAPE - UNKNOWN SUSPECT (STRANGER)' 'ALARM-RESIDENTIAL BURG'
#  'DV - SERVICE OF COURT ORDER' 'ARSON, BOMBS, EXPLO - ARSON'
#  'PEDESTRIAN VIOLATIONS' 'NARCOTICS - NARCOTICS WARRANT SERVICE'
#  'FRAUD - FRAUD, INCLUDING BUNCO' 'WARRANT - MISD PICKUP'
#  'PRISONER ESCORT - BUSY CODE' 'SEX OFFENSES (RAPE) - MOLESTING'
#  'NARCOTICS - FOUND , RECOVERED NARCOTICS'
#  'ANIMAL COMPLAINT - NOISE,STRAY,BITE' 'CROWD MGMNT (STAND BY ONLY)'
#  'TRAFFIC - COMMUNITY TRAFFIC COMPLAINT (CTC)'
#  'CASUALTY,NON-TRAF,NON-CRIM - NON-DRUG RELATED'
#  'SUSPICIOUS CIRCUM. - BUILDING (OPEN DOOR, ETC)' 'VICE - OTHER'
#  'AUTOMOBILES - ABANDONED CAR' 'TRAFFIC - PEDESTRIAN VIOLATION'
#  'PERSON - RUNAWAY' 'ASSIST OTHER AGENCY - CITY AGENCY'
#  'PROPERTY - FOUND PROPERTY'
#  'ARSON,BOMBS,EXPLO - BOMBS, EXPLO,LARGE FIREWORKS' 'KIDNAP - GENERAL'
#  'ORDER - VIOLATING DV COURT ORDER' 'DV - ASSIST VICTIM BY COURT ORDER'
#  'PREMISE CHECKS - LICENSE INSPECTIONS'
#  'BURG - RESD (INCL UNOCC STRUCTURES ON PROP)'
#  'PROWLER - TRESPASS, PARKS EXCLUSION'
#  'OBS - FIGHT - IP - PHYSICAL (NO WEAPONS)' 'TRESPASS' 'HAZARDS - HAZARDS'
#  'TRAFFIC - PARKING VIOL (EXCEPT ABANDONED CAR)'
#  'SUSPICIOUS STOP - OFFICER INITIATED ONVIEW'
#  'MISC MISD AND VIOLS - PARKS EXCLUSION' 'PERSON - FOUND PERSON'
#  'NUISANCE' 'DV - DOMESTIC THREATS BY PHONE OR WRITING'
#  'PERSON - MISSING PERSON' 'RAPE - KNOWN SUSPECT (ACQUAINTANCE)'
#  'DISTURBANCE' 'ESCAPE - PRISONER' 'HARAS - NO BIAS OR THREATS'
#  'TRAFFIC STOP - OFFICER INITIATED ONVIEW'
#  'ALARM-COMM ROBB (BANK, PANIC, DURESS)' 'WARRANT - FELONY PICKUP'
#  'SHOTS HEARD - IN PROGRESS' 'TRAFFIC - BLOCKING TRAFFIC'
#  'CASUALTY NON-TRAF NON-CRIM - DRUG RELATED (OD)'
#  'TRAFFIC - ASSIST MOTORIST' 'DEMO MGMNT (CONTROL TACTICS USED)'
#  'CHILD - CHILD ENDANGERMENT'
#  'THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)'
#  'SEX IN PUBLIC PLACE (INCL MASTURBATION)'
#  'ALARM-OTHER (VARDA,PDT,FIRE,LOCAL,METRO,ETC))'
#  'LIQUOR VIOLATIONS - ADULT' 'PREMISE CHECKS - BUSINESS CHECK'
#  'NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)' 'ASLT - DV'
#  'ASLT - DV CRITICAL' 'AUTO THEFT - VEH THEFT OR THEFT AND RECOVERY'
#  'ASSIST PUBLIC - NO WELFARE CHK OR DV ORDER SERVICE'
#  'UNKNOWN - COMPLAINT OF UNKNOWN NATURE'
#  'PREMISE CHECKS - HOMELESS ENCAMPMENT'
#  'WEAPN - GUN,DEADLY WPN (NO THRTS/ASLT/DIST)'
#  'HAZ - POTENTIAL THRT TO PHYS SAFETY' 'ROBBERY (INCL STRONG ARM)'
#  'DISTURBANCE - NOISE RESIDENTIAL'
#  'ASSIST OTHER AGENCY - EMERGENCY SERVICE' 'ASSAULTS - GANG RELATED'
#  'PREMISE CHECKS - REQUEST TO WATCH' 'PROPERTY - DAMAGE'
#  'ALARM-RESIDENTIAL PANIC OR DURESS'
#  'HELP THE OFFICER -ASSIST THE OFFICER (NON EMERG)' 'AUTO RECOVERY'
#  'CCR ONLY - ASSIST THE PUBLIC' 'HARBOR - BOAT ACCIDENT'
#  'BURG - COMM BURGLARY' 'OBS - MVC - NON INJURY, BLOCKING'
#  'PREMISE CHECK, OFFICER INITIATED ONVIEW ONLY'
#  'FIGHT - PHYSICAL (NO WEAPONS)' 'FOLLOW UP'
#  'ASLT - WITH OR W/O WPNS (NO SHOOTINGS)'
#  'URINATING, DEFECATING IN PUBLIC' 'ASSIST OTHER AGENCY - ROUTINE SERVICE'
#  'SEX OFFENSES (NON-RAPE) - FAILURE TO REGISTER'
#  'HOSPITAL GUARD ASSIGNMENT' 'CRISIS COMPLAINT - PICK-UP OR TRANSPORT'
#  'OBS WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/DIST)'
#  'TRAFFIC - BICYCLE VIOLATION' 'PERSON IN BEHAVIORAL/EMOTIONAL CRISIS'
#  'ASSAULTS - TELEPHONE, WRITING' 'SHOTS HEARD - DELAY'
#  'FIREWORKS (NO HAZARD)' 'OBS - PURSE SNATCH - IP/JO - ROBBERY'
#  'LEWD -  (EXPOSING, FLASHING)' 'HARBOR - VESSEL, THEFT'
#  'ORDER - VIOLATION OF COURT ORDER (NON DV)' 'BURG - OCCUPIED RESD'
#  'PEACE-STANDBY TO ASSURE (NO COURT ORDR SVC)' 'DOA - CASUALTY, DEAD BODY'
#  'SFD - ASSIST ON CRITICAL FIRE OR MEDIC RESPONSE'
#  'ASSIGNED DUTY - COMMUNITY,SCHOOL,SPECIAL EVENT'
#  'HARBOR - ASSIST BOATER (NON EMERG)' 'OFF DUTY EMPLOYMENT'
#  'CARJACKING - IP/JO - ROBBERY' 'ALARM-VEHICLE ALARMS' 'BOMB - THREATS'
#  'OBS - IP/JO - RACIAL, POLITICAL, SEXUAL MOTIVATION' 'NARCOTICS - FOUND'
#  'ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)'
#  'NARCOTICS WARRANT SERVICE' 'CCR ONLY - NON-OD SUD CALL'
#  'VICE - GAMBLING' 'RAPE' 'DOWN - CHECK FOR DOWN PERSON' 'OBS - PROWLER'
#  'SWATTING' 'COMMERCIAL SEXUAL EXPLOITATION OF MINORS (CSEC)'
#  'PROPERTY - FOUND' 'ASSIGNED DUTY - DETAIL BY SUPERVISOR'
#  'HARBOR - BOATING UNDER THE INFLUENCE' 'ASLT - CRITICAL (NO SHOOTINGS)'
#  'OBS - AUTO THEFT-IP/JO - VEHICLE, PLATES, TABS'
#  'ASSIGNED DUTY - STAKEOUT' 'DISTURBANCE - DV - NO ASLT'
#  'TRAFFIC - TRAFFIC CONTROL (SPECIAL EVENTS)' 'DOWN TIME - OUT OF SERVICE']
#
#  Call Type
# , ['911' '-' 'ONVIEW' 'TELEPHONE OTHER, NOT 911'
#  'ALARM CALL (NOT POLICE ALARM)' 'TEXT MESSAGE'
#  'SCHEDULED EVENT (RECURRING)' 'HISTORY CALL (RETRO)']
#
#  Officer Squad
# , ['NORTH PCT 2ND W - LINCOLN - PLATOON 1'
#  'NORTH PCT 2ND WATCH - B/N RELIEF'
#  'WEST PCT 1ST W - QUEEN (DAVID) - PLATOON 1'
#  'WEST PCT 3RD W - KING - PLATOON 1' 'SOUTH PCT 3RD W - SAM - PLATOON 2'
#  'SOUTHWEST PCT 2ND W - FRANK - PLATOON 2'
#  'SOUTH PCT 2ND W - ROBERT - PLATOON 2'
#  'NORTH PCT 1ST W - NORA (JOHN) - PLATOON 1'
#  'WEST PCT 3RD W - DAVID - PLATOON 1' 'WEST PCT 2ND W - QUEEN - PLATOON 1'
#  'WEST PCT 1ST W - KQ/DM RELIEF'
#  'NORTH PCT 2ND W - BOY (JOHN) - PLATOON 2'
#  'TRAINING - FIELD TRAINING SQUAD' 'EAST PCT 2ND W - CHARLIE RELIEF'
#  'EAST PCT 3RD W - GEORGE - PLATOON 2'
#  'WEST PCT 1ST W - DAVID - PLATOON 1'
#  'NORTH PCT 2ND W - UNION - PLATOON 1' 'WEST PCT 2ND W - D/M RELIEF'
#  'NORTH PCT OPS - ACT DAY' 'SOUTH PCT 3RD W - ROBERT (OCEAN) - PLATOON 1'
#  'SOUTH PCT 1ST W - R/S RELIEF' 'NORTH PCT 3RD W - B/N RELIEF'
#  'NORTH PCT 2ND W - BOY (JOHN) - PLATOON 1'
#  'WEST PCT 2ND W - SPECIAL BEATS' 'CRG - SQUAD 82C'
#  'SOUTH PCT 2ND W - ROBERT (OCEAN) - PLATOON 1'
#  'SOUTH PCT 3RD W - ROBERT - PLATOON 2'
#  'SOUTH PCT 3RD W - OCEAN - PLATOON 2'
#  'NORTH PCT 3RD W - UNION - PLATOON 1' 'WEST PCT 2ND W - MARY BEATS'
#  'SOUTH PCT 2ND W - R/S RELIEF'
#  'SOUTHWEST PCT 2ND W - WILLIAM - PLATOON 2'
#  'NORTH PCT 2ND W - UNION - PLATOON 2' 'WEST PCT 1ST W - KING - PLATOON 1'
#  'EAST PCT 1ST W - E/G RELIEF (CHARLIE)' 'NORTH PCT 3RD W - L/U RELIEF'
#  'WEST PCT 3RD W - MARY - PLATOON 1' 'NORTH PCT 2ND W - JOHN RELIEF'
#  'NORTH PCT 3RD W - NORA (JOHN) - PLATOON 1' 'EAST PCT 3RD W - EAST BEATS'
#  'SOUTH PCT 3RD W - R/S RELIEF' 'WEST PCT 3RD W - DAVID BEATS'
#  'SOUTH PCT 2ND W - SAM - PLATOON 2'
#  'EAST PCT 3RD W - CHARLIE - PLATOON 2' 'SOUTH PCT 2ND W - OCEAN RELIEF'
#  'NORTH PCT 3RD W - UNION - PLATOON 2'
#  'EAST PCT 2ND W - EDWARD - PLATOON 2' 'WEST PCT 2ND W - DAVID BEATS'
#  'NORTH PCT 3RD W - LINCOLN - PLATOON 1'
#  'NORTH PCT 3RD W - BOY (JOHN) - PLATOON 1'
#  'SOUTHWEST PCT - 3RD WATCH - F/W RELIEF'
#  'NORTH PCT 2ND W - NORA (JOHN) - PLATOON 1'
#  'EAST PCT 3RD W - EDWARD - PLATOON 2' 'WEST PCT 2ND W - KING BEATS'
#  'WEST PCT 2ND W - DAVID - PLATOON 1'
#  'EAST PCT 1ST W - GEORGE (CHARLIE) - PLATOON 2'
#  'WEST PCT 1ST W - MARY (DAVID) - PLATOON 2'
#  'SOUTH PCT 1ST W - ROBERT - PLATOON 2'
#  'NORTH PCT 1ST W - UNION - PLATOON 1'
#  'WEST PCT 3RD W - QUEEN - PLATOON 1' 'WEST PCT 2ND W - DAVID - PLATOON 2'
#  'WEST PCT 3RD W - D/M RELIEF' 'EAST PCT 2ND W - GEORGE - PLATOON 2'
#  'NORTH PCT 2ND WATCH - NORTH BEATS'
#  'EAST PCT 2ND W - EDWARD (CHARLIE) - PLATOON 1'
#  'WEST PCT 3RD W - K/Q RELIEF' 'WEST PCT 2ND W - KING - PLATOON 1'
#  'CRG - SQUAD 81B' 'HARBOR - SQUAD B' 'EAST PCT 3RD W - E/G RELIEF'
#  'WEST PCT 2ND W - MARY - PLATOON 1' 'SOUTH PCT 1ST W - SAM - PLATOON 2'
#  'SOUTHWEST PCT 3RD W - WILLIAM - PLATOON 2' nan
#  'SOUTH PCT OPS - NIGHT ACT' 'NORTH PCT 2ND W - L/U RELIEF'
#  'NORTH PCT 1ST W - LINCOLN (UNION) - PLATOON 1'
#  'EAST PCT 1ST W - EDWARD (CHARLIE) - PLATOON 1' 'CRG - SQUAD 81A'
#  'SOUTH PCT 2ND W - OCEAN - PLATOON 2'
#  'SOUTHWEST PCT 3RD W - FRANK - PLATOON 1'
#  'EAST PCT 3RD W - GEORGE (CHARLIE) - PLATOON 1'
#  'SOUTHWEST PCT 2ND W - SOUTHWEST BEATS'
#  'CRISIS INTERVENTION COORDINATION SQUAD'
#  'WEST PCT 3RD W - MARY - PLATOON 2'
#  'NORTH PCT 2ND W - NORA (JOHN) - PLATOON 2' 'TRAF - DUI SQUAD'
#  'SOUTHWEST PCT - 1ST WATCH - F/W RELIEF' 'EAST PCT 2ND W - E/G RELIEF'
#  'EAST PCT 1ST W - EDWARD (CHARLIE) - PLATOON 2'
#  'EAST PCT 3RD W - EDWARD (CHARLIE) - PLATOON 1' 'NORTH PCT OPS - CPT'
#  'EAST PCT 2ND W - CHARLIE - PLATOON 2' 'CRG - SQUAD 81E'
#  'NORTH PCT 2ND W - NORA' 'NORTH PCT 3RD W - LINCOLN - PLATOON 2'
#  'CRG - SQUAD 81C' 'HR - HUMAN RESOURCES  - DEPT UNAVAIL PERSONNEL'
#  'NORTH PCT 1ST W - B/N RELIEF (JOHN)'
#  'SOUTHWEST PCT 2ND WATCH - F/W RELIEF'
#  'SOUTH PCT 3RD W - SAM (OCEAN) - PLATOON 1'
#  'WEST PCT 1ST W - KING - PLATOON 2' 'SOUTH PCT 1ST W - OCEAN - PLATOON 2'
#  'EAST PCT 2ND W - GEORGE (CHARLIE) - PLATOON 1'
#  'SOUTHWEST PCT 3RD W - WILLIAM - PLATOON 1'
#  'EAST PCT 3RD WATCH - CHARLIE RELIEF' 'WEST PCT 2ND W - K/Q RELIEF'
#  'CRG - SQUAD 82E' 'WEST PCT 2ND W - MARY - PLATOON 2'
#  'SOUTHWEST PCT 1ST W - FRANK - PLATOON 2'
#  'NORTH PCT 1ST W - BOY (JOHN) - PLATOON 1' 'SOUTHWEST PCT OPS - CPT'
#  'NORTH PCT 1ST W - L/U RELIEF'
#  'NORTH PCT 3RD W - NORA - (JOHN) - PLATOON 2'
#  'SOUTHWEST PCT 2ND W - FRANK - PLATOON 1' 'WEST PCT OPS - NIGHT BIKES'
#  'GUN VIOLENCE REDUCTION SQUAD B' 'CRG - SQUAD 81D'
#  'SOUTHWEST PCT 1ST W - WILLIAM - PLATOON 2'
#  'NORTH PCT 3RD W - JOHN - PLATOON 1' 'FORCE REVIEW SQUAD'
#  'NORTH PCT 3RD W - JOHN RELIEF' 'SOUTH PCT OPS - DAY ACT'
#  'SOUTH PCT 3RD W - OCEAN RELIEF' 'WEST PCT 2ND W - KING - PLATOON 2'
#  'EAST PCT 1ST W - GEORGE (CHARLIE) - PLATOON 1'
#  'NORTH PCT 2ND W - JOHN - PLATOON 1' 'GUN VIOLENCE REDUCTION SQUAD C'
#  'EAST PCT 2ND W - BEATS' 'CRISIS RESPONSE SQUAD'
#  'WEST PCT 3RD W - KING - PLATOON 2' 'EAST PCT 2ND W - CHARLIE'
#  'WEST PCT 1ST W - QUEEN (DAVID) - PLATOON 2' 'CRG - SQUAD 82D'
#  'GUN VIOLENCE REDUCTION SQUAD A' 'SOUTHWEST PCT OPS - NIGHT ACT'
#  'SOUTH PCT 1ST W - ROBERT (OCEAN) - PLATOON 1' 'BURG/THEFT/JUV - NORTH'
#  'SOUTH PCT 1ST W - SAM (OCEAN) - PLATOON 1' 'SOUTH PCT OPS - BURG/THEFT'
#  'SOUTH PCT 2ND W - SAM BEATS' 'ALTERNATIVE RESPONSE TEAM (ART) - SQUAD B'
#  'EAST PCT 2ND W - GEORGE' 'SOUTHWEST PCT 3RD W - FRANK - PLATOON 2'
#  'WEST PCT OPS - DAY BIKES' 'HR - DEPARTMENT UNAVAILABLE PERSONNEL'
#  'WEST PCT OPS - CPT' 'SAU SQUAD A' 'CANINE - SQUAD A'
#  'WEST PCT 3RD W - QUEEN - PLATOON 2' 'CRG - SQUAD 82A'
#  'EAST PCT OPS - NIGHT ACT' 'NORTH PCT 1ST W - NORA (JOHN) - PLATOON 2'
#  'NORTH PCT 1ST W - BOY (JOHN) -  PLATOON 2'
#  'WEST PCT 2ND W - QUEEN - PLATOON 2' 'SAU SQUAD B'
#  'TRAF - COLLISION INVESTIGATION'
#  'ICAC - INTERNET CRIMES AGAINST CHILDREN SQUAD'
#  'WEST PCT 1ST W - MARY (DAVID) - PLATOON 1'
#  'SOUTH PCT 2ND W - SAM (OCEAN) - PLATOON 1'
#  'COMMUNITY OUTREACH - YOUTH VIOLENCE - SCHOOLS' 'EAST PCT OPS - CPT'
#  'DV SQUAD C - ELDER ABUSE' 'WEST PCT OPS - BURG/THEFT'
#  'SWAT - DAY SQUAD 1' 'JOINT ENFORCEMENT TEAM (JET)' 'CANINE - SQUAD C'
#  'WEST PCT 3RD W - DAVID - PLATOON 2'
#  'NORTH PCT 1ST W - LINCOLN (UNION) - PLATOON 2' 'HARBOR - SQUAD A'
#  'SOUTHWEST PCT 2ND W - WILLIAM' 'WEST PCT 3RD W - DAVID'
#  'SOUTHWEST PCT 2ND W - WILLIAM - PLATOON 1'
#  'SPECIAL OPS BUREAU - SPECIAL ASSIGNMENTS' 'SWAT - NIGHT SQUAD 1'
#  'WEST PCT 1ST W - KING/QUEEN' 'WEST PCT 2ND W - KING'
#  'SOUTH PCT OPS - CPT' 'TRAF - AM ENFORCEMENT' 'CANINE - NIGHT SQUAD'
#  'NORTH PCT 2ND W - LINCOLN - PLATOON 2' 'PUBLIC AFFAIRS SQUAD'
#  'COP - STRATEGIC COMMUNICATIONS - PUBLIC AFFAIRS'
#  'WEST PCT 1ST W - DAVID/MARY' 'JOINT ENFORCEMENT TEAM'
#  'SOUTH PCT 1ST W - SAM' 'AUTO THEFT'
#  'COMMUNITY OUTREACH - YOUTH VIOLENCE-SCHOOLS DETAIL'
#  'CCI - MAJOR CRIMES TASK FORCE' 'DV SQUAD A - INVESTIGATIONS'
#  'ROBBERY SQUAD B' 'CRG - SQUAD 82B' 'WEST PCT 2ND W - MARY'
#  'BURG/THEFT/JUV - EAST' 'MAJOR CRIMES TASK FORCE' 'PAWN DETAIL'
#  'ROBBERY SQUAD A' 'SOUTHWEST PCT 1ST W - WILLIAM - PLATOON 1'
#  'NORTH PCT 3RD W - BOY (JOHN) - PLATOON 2' 'EAST PCT 3RD W - EDWARD'
#  'SOUTHWEST PCT 1ST W - WILLIAM' 'WEST PCT OPS - SEA CTR'
#  'SWAT - DAY SQUAD 2' 'HARBOR - SQUAD D' 'SVU SQUAD E - SEXUAL ASSAULT'
#  'SOUTHWEST PCT 2ND W - FRANK' 'WEST PCT OPS - COMMERCIAL SEC'
#  'TRAF - MOTORCYCLE - T2 SQUAD' 'HOMICIDE SQUAD B'
#  'FORCE INVESTIGATIONS SQUAD' 'CANINE - DAY SQUAD'
#  'NORTH PCT 3RD W - NORA' 'CCI - GENERAL INVESTIGATIONS SQUAD C'
#  'NARC - PROACTIVE SQUAD B' 'SWAT - DAY SQUAD 3'
#  'HR - BLEA - ACADEMY RECRUITS' 'NORTH PCT 1ST W - LINCOLN'
#  'ALTERNATIVE RESPONSE TEAM (ART) - SQUAD A'
#  'TRAINING - ADVANCED - SQAUD B' 'SOUTHWEST PCT 1ST W - FRANK - PLATOON 1'
#  'EAST PCT OPS - BURG/THEFT' 'NORTH PCT 1ST W - BOY (JOHN)'
#  'ZOLD CRIME ANALYSIS UNIT - ANALYSTS' 'BURG/THEFT/JUV - SOUTH'
#  'SOUTH PCT 2ND W - SAM' 'SOUTH PCT 1ST W - ROBERT'
#  'WEST PCT OPS - MOUNTED PATROL' 'HUMAN TRAFFICKING SQUAD'
#  'TRAINING - ADVANCED UNIT ADMINISTRATION' 'GUILD PRESIDENT'
#  'NORTH PCT 3RD W - JOHN' 'TRAF - MOTORCYCLE UNIT - T4 SQUAD'
#  'OPS BUREAU - SPECIAL ASSIGNMENTS' 'WEST PCT 3RD W - MARY'
#  'CCI - GENERAL INVESTIGATIONS SQUAD B' 'SOUTH PCT 3RD W - ROBERT'
#  'TRAINING - LEARNING MANAGEMENT SYSTEM' 'TRAF - PM ENFORCEMENT'
#  'EAST PCT 1ST W - EDWARD (CHARLIE)' 'TRAINING - WSCJC SQUAD (ACADEMY)'
#  'NORTH PCT 3RD W - LINCOLN' 'SOUTHWEST PCT 3RD W - FRANK'
#  'BURG/THEFT/JUV - WEST' 'NORTH PCT 2ND W - PCT SUPPORT'
#  'WEST PCT 3RD W - QUEEN' 'NORTH PCT 2ND W - LINCOLN'
#  'CRG - ADMINISTRATION'
#  'COMMUNITY OUTREACH - YOUTH VIOLENCE -SCHOOLS DETAIL'
#  'WEST PCT 3RD W - KING' 'WEST PCT - ITRU SQUAD' 'WEST PCT 2ND W - QUEEN'
#  'NARC - PROACTIVE SQUAD C' 'SVU SQUAD A - DV INVESTIGATIONS'
#  'NARC - PROACTIVE SQUAD A' 'NORTH PCT 3RD W - BOY'
#  'TRAF - MOTORCYCLE UNIT - T3 SQUAD' 'CSI SQUAD'
#  'NORTH PCT OPS - BURG/THEFT' 'HUMAN TRAFFICKING - SQUAD A'
#  'WEST PCT OPS - ACT NIGHT' 'SOUTH PCT 3RD W - SAM'
#  'SOUTH PCT 2ND W - ROBERT' 'CCI - GENERAL INVESTIGATIONS SQUAD A'
#  'SOUTHWEST PCT OPS - BURG/THEFT' 'RECORDS - DAY SHIFT'
#  'SVU SQUAD D - ORDER SERVICE'
#  'METRO - SPECIAL EVENT PLANNING / SPOC (OPERATIONS CENTER)'
#  'NORTH PCT 1ST W - NORA (JOHN)' 'TRAINING - ADVANCED - SQUAD C'
#  'COMM - INTERNET AND TELEPHONE REPORTING (ITRU)' 'ARSON/BOMB - SQUAD A'
#  'FORENSICS - CRIME SCENE INVESTIGATIONS' 'SOUTHWEST PCT OPS - DAY ACT'
#  'TRAF - MOTORCYCLE UNIT - T2 SQUAD' 'EAST PCT 2ND W - EDWARD'
#  'DV SQUAD D - ORDER SERVICE'
#  'COMMUNITY OUTREACH - SPECIAL PROJECTS DETAIL' 'HOMICIDE SQUAD A']
#
#  Arrest Flag
# , ['N' 'Y']
#
#  Frisk Flag
# , ['N' 'Y' '-']
#
#  Precinct
# , ['North' 'West' '-' 'Southwest' 'South' 'East' 'OOJ' 'Unknown' 'FK ERROR']
#
#  Sector
# , ['L' 'Q' 'K' 'D' '-' 'F' 'R' 'N' 'B' 'M' 'S' 'J' 'U' 'O' 'G' 'E' 'C' 'W'
#  '99' 'OOJ']
#
#  Beat
# , ['L3' 'Q2' 'K3' 'D2' '-' 'F1' 'R2' 'N3' 'D3' 'B1' 'D1' 'R3' 'K2' 'N2' 'M3'
#  'S3' 'J1' 'B2' 'U1' 'F3' 'O1' 'S1' 'R1' 'G2' 'U2' 'G3' 'Q3' 'N1' 'E3'
#  'M2' 'C3' 'O2' 'U3' 'Q1' 'E1' 'W2' 'K1' 'M1' 'J2' 'W3' 'F2' 'O3' 'J3'
#  'E2' 'C2' 'L2' 'S2' 'G1' 'W1' 'L1' 'B3' 'C1' 'OOJ' '99' 'S']

# %%
#check value counts for each column
for coln in df:
    value_count = df[coln].value_counts()
    print(f"{coln}:\n{value_count}\n")
# Out:
# Subject Age Group:
# 26 - 35         21576
# 36 - 45         14705
# 18 - 25         12081
# 46 - 55          8189
# 56 and Above     3426
# 1 - 17           2392
# -                2368
# Name: Subject Age Group, dtype: int64
#
# Subject ID:
# -1              35221
#  7753260438        30
#  7774286580        22
#  21375848115       22
#  7726918259        22
#                 ...
#  7727594916         1
#  7731121570         1
#  37999033568        1
#  31734906260        1
#  16219707395        1
# Name: Subject ID, Length: 18941, dtype: int64
#
# GO / SC Num:
# 20150000190790    16
# 20160000378750    16
# 20240000319277    15
# 20230000049052    14
# 20180000134604    14
#                   ..
# 20200000067947     1
# 20170000181613     1
# 20160000420117     1
# 20210000140555     1
# 20180000000296     1
# Name: GO / SC Num, Length: 52005, dtype: int64
#
# Terry Stop ID:
# 27511831225    3
# 36014210659    3
# 55477887782    3
# 19324329995    3
# 15045077325    3
#               ..
# 499161         1
# 103896         1
# 12715288022    1
# 40982005202    1
# 131072         1
# Name: Terry Stop ID, Length: 64620, dtype: int64
#
# Stop Resolution:
# Field Contact               32234
# Offense Report              16002
# Arrest                      15545
# Referred for Prosecution      728
# Citation / Infraction         228
# Name: Stop Resolution, dtype: int64
#
# Weapon Type:
# None                                    32565
# -                                       28035
# Knife/Cutting/Stabbing Instrument        1494
# Lethal Cutting Instrument                1482
# Handgun                                   431
# Blunt Object/Striking Implement           199
# Firearm                                   131
# Firearm Other                             100
# Other Firearm                              85
# Mace/Pepper Spray                          64
# Club, Blackjack, Brass Knuckles            49
# None/Not Applicable                        21
# Taser/Stun Gun                             20
# Firearm (unk type)                         15
# Fire/Incendiary Device                     13
# Rifle                                      11
# Club                                        9
# Shotgun                                     6
# Personal Weapons (hands, feet, etc.)        2
# Automatic Handgun                           2
# Brass Knuckles                              1
# Poison                                      1
# Blackjack                                   1
# Name: Weapon Type, dtype: int64
#
# Officer ID:
# 7456    551
# 7690    373
# 7773    372
# 7634    365
# 8894    357
#        ...
# 6287      1
# 6845      1
# 5729      1
# 6782      1
# 7448      1
# Name: Officer ID, Length: 1435, dtype: int64
#
# Officer YOB:
# 1986    4141
# 1987    3941
# 1991    3588
# 1992    3533
# 1990    3313
# 1989    3255
# 1984    3228
# 1985    3005
# 1988    2691
# 1995    2668
# 1993    2487
# 1982    2101
# 1983    2042
# 1979    1942
# 1994    1899
# 1981    1766
# 1996    1565
# 1976    1512
# 1971    1327
# 1997    1308
# 1978    1303
# 1977    1193
# 1973    1115
# 1980    1028
# 1967     852
# 1970     752
# 1968     702
# 1975     665
# 1969     642
# 1974     610
# 1998     495
# 1972     494
# 1964     478
# 1962     465
# 1965     425
# 1961     267
# 1963     265
# 1966     253
# 1999     239
# 1958     223
# 1959     174
# 2000     167
# 1960     161
# 2001     106
# 2002      65
# 1900      50
# 1956      48
# 1954      44
# 1957      43
# 1953      41
# 1955      21
# 2003      11
# 1948      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: Officer YOB, dtype: int64
#
# Officer Gender:
# Male             57366
# Female            7341
# Non-Specified       30
# Name: Officer Gender, dtype: int64
#
# Officer Race:
# White                                        46063
# Two or More Races                             4679
# Hispanic                                      4304
# Asian                                         3320
# Declined to Answer                            2893
# Black or African American                     2582
# Native Hawaiian or Other Pacific Islander      599
# American Indian or Alaska Native               247
# Unknown                                         50
# Name: Officer Race, dtype: int64
#
# Subject Perceived Race:
# White                                        31649
# Black or African American                    19516
# Unknown                                       4944
# Asian                                         2231
# -                                             1819
# American Indian or Alaska Native              1746
# Hispanic                                      1684
# Multi-Racial                                   809
# Native Hawaiian or Other Pacific Islander      186
# Other                                          152
# MULTIPLE SUBJECTS                                1
# Name: Subject Perceived Race, dtype: int64
#
# Subject Perceived Gender:
# Male                                                         51093
# Female                                                       12890
# Unable to Determine                                            326
# -                                                              244
# Unknown                                                        118
# Gender Diverse (gender non-conforming and/or transgender)       65
# MULTIPLE SUBJECTS                                                1
# Name: Subject Perceived Gender, dtype: int64
#
# Reported Date:
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-05-06T00:00:00      1
# 2015-05-10T00:00:00      1
# 2015-03-28T00:00:00      1
# 2024-06-29T00:00:00      1
# 2015-03-31T00:00:00      1
# Name: Reported Date, Length: 3829, dtype: int64
#
# Reported Time:
# 03:09:00.0000000    52
# 02:56:00.0000000    52
# 17:00:00.0000000    51
# 19:18:00.0000000    51
# 03:13:00.0000000    51
#                     ..
# 02:46:38.0000000     1
# 01:32:01.0000000     1
# 00:24:42.0000000     1
# 19:58:57.0000000     1
# 05:15:37.0000000     1
# Name: Reported Time, Length: 26254, dtype: int64
#
# Initial Call Type:
# -                                                     13602
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW             5348
# SUSPICIOUS PERSON, VEHICLE, OR INCIDENT                4512
# DISTURBANCE                                            3305
# ASLT - CRITICAL (NO SHOOTINGS)                         2816
#                                                       ...
# HARBOR - WATER EMERGENCIES                                1
# ABANDONED VEHICLE                                         1
# ANIMAL - DANGEROUS                                        1
# ASSIGNED DUTY - STAKEOUT                                  1
# OBS - UNKNOWN - ANI/ALI - PAY PHN (INCL OPEN LINE)        1
# Name: Initial Call Type, Length: 186, dtype: int64
#
# Final Call Type:
# -                                                     13602
# SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON                 6167
# PROWLER - TRESPASS                                     4572
# DISTURBANCE - OTHER                                    3893
# ASSAULTS, OTHER                                        3236
#                                                       ...
# DOWN TIME - OUT OF SERVICE                                1
# FIGHT - PHYSICAL (NO WEAPONS)                             1
# ASLT - DV CRITICAL                                        1
# ESCAPE - PRISONER                                         1
# OBS - IP/JO - RACIAL, POLITICAL, SEXUAL MOTIVATION        1
# Name: Final Call Type, Length: 203, dtype: int64
#
# Call Type:
# 911                              30545
# ONVIEW                           15702
# -                                13602
# TELEPHONE OTHER, NOT 911          4316
# ALARM CALL (NOT POLICE ALARM)      540
# TEXT MESSAGE                        30
# HISTORY CALL (RETRO)                 1
# SCHEDULED EVENT (RECURRING)          1
# Name: Call Type, dtype: int64
#
# Officer Squad:
# TRAINING - FIELD TRAINING SQUAD                 6998
# WEST PCT 1ST W - DAVID - PLATOON 1              1706
# WEST PCT 3RD W - KING - PLATOON 1               1592
# WEST PCT 1ST W - KING - PLATOON 1               1377
# SOUTHWEST PCT 2ND W - FRANK - PLATOON 2         1302
#                                                 ...
# RECORDS - DAY SHIFT                                1
# TRAINING - LEARNING MANAGEMENT SYSTEM              1
# HOMICIDE SQUAD A                                   1
# NORTH PCT 3RD W - LINCOLN                          1
# COMMUNITY OUTREACH - SPECIAL PROJECTS DETAIL       1
# Name: Officer Squad, Length: 277, dtype: int64
#
# Arrest Flag:
# N    57400
# Y     7337
# Name: Arrest Flag, dtype: int64
#
# Frisk Flag:
# N    48527
# Y    15732
# -      478
# Name: Frisk Flag, dtype: int64
# Precinct:
# West         18416
# North        13464
# -            10822
# East          8871
# South         7833
# Southwest     4989
# Unknown        200
# OOJ            120
# FK ERROR        22
# Name: Precinct, dtype: int64
#
# Sector:
# -      10973
# K       6495
# M       5539
# E       4677
# N       3850
# D       3644
# R       3029
# F       2974
# B       2847
# Q       2734
# L       2605
# O       2442
# S       2363
# U       2361
# G       2291
# W       2010
# C       1901
# J       1799
# 99       138
# OOJ       65
# Name: Sector, dtype: int64
#
# Beat:
# -      10967
# K3      3901
# M3      2756
# N3      1944
# E2      1942
# E1      1581
# R2      1455
# D1      1452
# N2      1440
# K2      1433
# M2      1403
# M1      1383
# D2      1342
# Q3      1309
# F2      1237
# K1      1161
# E3      1152
# B2      1085
# U2      1074
# B1      1060
# O1       984
# S2       918
# L2       905
# F3       877
# F1       860
# L1       852
# D3       850
# L3       848
# G2       847
# W2       846
# R1       846
# U1       809
# Q2       794
# S3       786
# G3       782
# C1       777
# O3       775
# R3       728
# B3       707
# J3       688
# W1       684
# O2       683
# G1       660
# S1       659
# C3       659
# J1       654
# Q1       631
# W3       481
# U3       478
# C2       466
# N1       464
# J2       457
# 99       139
# OOJ       64
# S          2
# Name: Beat, dtype: int64

# %%
#Make a copy of the original dataset
df1 = df.copy(deep=True)
df1.head()
# Out:
#   Subject Age Group   Subject ID     GO / SC Num  Terry Stop ID  \
# 0           26 - 35           -1  20170000036835         234548
# 1           46 - 55           -1  20180000275629         481899
# 2           36 - 45  49326761681  20230000118635    49327076666
# 3           36 - 45  53986235598  20240000029589    53986202139
# 4           18 - 25           -1  20150000002928          54115
#
#   Stop Resolution                        Weapon Type Officer ID  Officer YOB  \
# 0  Offense Report                               None       4852         1953
# 1   Field Contact                               None       8544         1993
# 2   Field Contact  Knife/Cutting/Stabbing Instrument       7766         1984
# 3   Field Contact                                  -       8723         1994
# 4   Field Contact                               None       7745         1988
#
#   Officer Gender        Officer Race  ...     Reported Time  \
# 0           Male               Asian  ...  18:36:00.0000000
# 1         Female            Hispanic  ...  13:47:00.0000000
# 2           Male               White  ...  07:25:58.0000000
# 3           Male               White  ...  02:50:52.0000000
# 4         Female  Declined to Answer  ...  00:22:00.0000000
#
#                             Initial Call Type  \
# 0                                 DISTURBANCE
# 1                                           -
# 2          OBS - DOWN - CHECK FOR PERSON DOWN
# 3  SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 4                                           -
#
#                           Final Call Type Call Type  \
# 0                        THEFT - SHOPLIFT       911
# 1                                       -         -
# 2  SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON    ONVIEW
# 3                     DISTURBANCE - OTHER    ONVIEW
# 4                                       -         -
#
#                                 Officer Squad Arrest Flag Frisk Flag Precinct  \
# 0       NORTH PCT 2ND W - LINCOLN - PLATOON 1           N          N    North
# 1            NORTH PCT 2ND WATCH - B/N RELIEF           N          N     West
# 2  WEST PCT 1ST W - QUEEN (DAVID) - PLATOON 1           N          Y     West
# 3           WEST PCT 3RD W - KING - PLATOON 1           N          N     West
# 4           SOUTH PCT 3RD W - SAM - PLATOON 2           N          N        -
#
#   Sector Beat
# 0      L   L3
# 1      Q   Q2
# 2      K   K3
# 3      D   D2
# 4      -    -
#
# [5 rows x 23 columns]

# %%
#Check the column names
df1.columns
# Out:
# Index(['Subject Age Group', 'Subject ID', 'GO / SC Num', 'Terry Stop ID',
#        'Stop Resolution', 'Weapon Type', 'Officer ID', 'Officer YOB',
#        'Officer Gender', 'Officer Race', 'Subject Perceived Race',
#        'Subject Perceived Gender', 'Reported Date', 'Reported Time',
#        'Initial Call Type', 'Final Call Type', 'Call Type', 'Officer Squad',
#        'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %%
#Rename the columns to remove whitespaces and convert the column names to lowercase
df1.columns = df1.columns.str.replace(" ", "_").str.lower()
df1.columns
# Out:
# Index(['subject_age_group', 'subject_id', 'go_/_sc_num', 'terry_stop_id',
#        'stop_resolution', 'weapon_type', 'officer_id', 'officer_yob',
#        'officer_gender', 'officer_race', 'subject_perceived_race',
#        'subject_perceived_gender', 'reported_date', 'reported_time',
#        'initial_call_type', 'final_call_type', 'call_type', 'officer_squad',
#        'arrest_flag', 'frisk_flag', 'precinct', 'sector', 'beat'],
#       dtype='object')

# %%
#Strip spaces from all string columns
df1 = df1.apply(lambda col: col.str.strip() if col.dtype == "object" else col)

# %%
def replace_dash_with_unknown(df1):
    """
    Replaces dash-like values ('-', '–', '—')  
    across all object columns in the DataFrame.
    """
    
    # Replace dash-like values with 'Unknown'
    df1 = df1.replace(r"^[-–—]$", "Unknown", regex=True)
    
    return df1

df1 = replace_dash_with_unknown(df1)

# %%
df1["weapon_type"] = df1["weapon_type"].replace(
    {
        "Firearm": "Other Firearm",
        "Firearm Other": "Other Firearm",
        "Firearm (unk type)": "Other Firearm",
        "Lethal Cutting Instrument": "Knife/Cutting/Stabbing Instrument", 
        "None/Not Applicable": "None",
        "Automatic Handgun":"Handgun",
        "Club": "Blunt Object/Striking Implement",
        "Blackjack": "Blunt Object/Striking Implement",
        "Brass Knuckles": "Blunt Object/Striking Implement",
        "Club, Blackjack, Brass Knuckles": "Blunt Object/Striking Implement"
    }
)
df1["weapon_type"].value_counts()
# Out:
# None                                    32586
# Unknown                                 28035
# Knife/Cutting/Stabbing Instrument        2976
# Handgun                                   433
# Other Firearm                             331
# Blunt Object/Striking Implement           259
# Mace/Pepper Spray                          64
# Taser/Stun Gun                             20
# Fire/Incendiary Device                     13
# Rifle                                      11
# Shotgun                                     6
# Personal Weapons (hands, feet, etc.)        2
# Poison                                      1
# Name: weapon_type, dtype: int64

# %%
df1["officer_race"] = df1["officer_race"].replace("Declined to Answer", "Unknown")
df1["officer_race"].value_counts()
# Out:
# White                                        46063
# Two or More Races                             4679
# Hispanic                                      4304
# Asian                                         3320
# Unknown                                       2943
# Black or African American                     2582
# Native Hawaiian or Other Pacific Islander      599
# American Indian or Alaska Native               247
# Name: officer_race, dtype: int64

# %%
df1["subject_perceived_race"] = df1["subject_perceived_race"].replace("MULTIPLE SUBJECTS", "Other")       
df1["subject_perceived_race"].value_counts()
# Out:
# White                                        31649
# Black or African American                    19516
# Unknown                                       6763
# Asian                                         2231
# American Indian or Alaska Native              1746
# Hispanic                                      1684
# Multi-Racial                                   809
# Native Hawaiian or Other Pacific Islander      186
# Other                                          153
# Name: subject_perceived_race, dtype: int64

# %%
df1["subject_perceived_gender"] = df1["subject_perceived_gender"].replace(
    {
    "Unable to Determine": "Unknown",
     "MULTIPLE SUBJECTS": "Unknown"  
    }
)
df1["subject_perceived_gender"].value_counts()
# Out:
# Male                                                         51093
# Female                                                       12890
# Unknown                                                        689
# Gender Diverse (gender non-conforming and/or transgender)       65
# Name: subject_perceived_gender, dtype: int64

# %%
df1["precinct"] = df1["precinct"].replace("FK ERROR", "Unknown")       
df1["precinct"].value_counts()
# Out:
# West         18416
# North        13464
# Unknown      11044
# East          8871
# South         7833
# Southwest     4989
# OOJ            120
# Name: precinct, dtype: int64

# %%
#check for duplicates
df1.duplicated().sum()
# Out:
# 1

# %%
#check value counts for each column
for coln in df1:
    value_count = df1[coln].value_counts()
    print(f"{coln}:\n{value_count}\n")
# Out:
# subject_age_group:
# 26 - 35         21576
# 36 - 45         14705
# 18 - 25         12081
# 46 - 55          8189
# 56 and Above     3426
# 1 - 17           2392
# Unknown          2368
# Name: subject_age_group, dtype: int64
#
# subject_id:
# -1              35221
#  7753260438        30
#  7774286580        22
#  21375848115       22
#  7726918259        22
#                 ...
#  7727594916         1
#  7731121570         1
#  37999033568        1
#  31734906260        1
#  16219707395        1
# Name: subject_id, Length: 18941, dtype: int64
#
# go_/_sc_num:
# 20150000190790    16
# 20160000378750    16
# 20240000319277    15
# 20230000049052    14
# 20180000134604    14
#                   ..
# 20200000067947     1
# 20170000181613     1
# 20160000420117     1
# 20210000140555     1
# 20180000000296     1
# Name: go_/_sc_num, Length: 52005, dtype: int64
#
# terry_stop_id:
# 27511831225    3
# 36014210659    3
# 55477887782    3
# 19324329995    3
# 15045077325    3
#               ..
# 499161         1
# 103896         1
# 12715288022    1
# 40982005202    1
# 131072         1
# Name: terry_stop_id, Length: 64620, dtype: int64
#
# stop_resolution:
# Field Contact               32234
# Offense Report              16002
# Arrest                      15545
# Referred for Prosecution      728
# Citation / Infraction         228
# Name: stop_resolution, dtype: int64
#
# weapon_type:
# None                                    32586
# Unknown                                 28035
# Knife/Cutting/Stabbing Instrument        2976
# Handgun                                   433
# Other Firearm                             331
# Blunt Object/Striking Implement           259
# Mace/Pepper Spray                          64
# Taser/Stun Gun                             20
# Fire/Incendiary Device                     13
# Rifle                                      11
# Shotgun                                     6
# Personal Weapons (hands, feet, etc.)        2
# Poison                                      1
# Name: weapon_type, dtype: int64
#
# officer_id:
# 7456    551
# 7690    373
# 7773    372
# 7634    365
# 8894    357
#        ...
# 6045      1
# 5469      1
# 6162      1
# 5917      1
# 5617      1
# Name: officer_id, Length: 1435, dtype: int64
#
# officer_yob:
# 1986    4141
# 1987    3941
# 1991    3588
# 1992    3533
# 1990    3313
# 1989    3255
# 1984    3228
# 1985    3005
# 1988    2691
# 1995    2668
# 1993    2487
# 1982    2101
# 1983    2042
# 1979    1942
# 1994    1899
# 1981    1766
# 1996    1565
# 1976    1512
# 1971    1327
# 1997    1308
# 1978    1303
# 1977    1193
# 1973    1115
# 1980    1028
# 1967     852
# 1970     752
# 1968     702
# 1975     665
# 1969     642
# 1974     610
# 1998     495
# 1972     494
# 1964     478
# 1962     465
# 1965     425
# 1961     267
# 1963     265
# 1966     253
# 1999     239
# 1958     223
# 1959     174
# 2000     167
# 1960     161
# 2001     106
# 2002      65
# 1900      50
# 1956      48
# 1954      44
# 1957      43
# 1953      41
# 1955      21
# 2003      11
# 1948      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: officer_yob, dtype: int64
#
# officer_gender:
# Male             57366
# Female            7341
# Non-Specified       30
# Name: officer_gender, dtype: int64
#
# officer_race:
# White                                        46063
# Two or More Races                             4679
# Hispanic                                      4304
# Asian                                         3320
# Unknown                                       2943
# Black or African American                     2582
# Native Hawaiian or Other Pacific Islander      599
# American Indian or Alaska Native               247
# Name: officer_race, dtype: int64
#
# subject_perceived_race:
# White                                        31649
# Black or African American                    19516
# Unknown                                       6763
# Asian                                         2231
# American Indian or Alaska Native              1746
# Hispanic                                      1684
# Multi-Racial                                   809
# Native Hawaiian or Other Pacific Islander      186
# Other                                          153
# Name: subject_perceived_race, dtype: int64
#
# subject_perceived_gender:
# Male                                                         51093
# Female                                                       12890
# Unknown                                                        689
# Gender Diverse (gender non-conforming and/or transgender)       65
# Name: subject_perceived_gender, dtype: int64
#
# reported_date:
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-05-06T00:00:00      1
# 2015-05-10T00:00:00      1
# 2015-03-28T00:00:00      1
# 2024-06-29T00:00:00      1
# 2015-03-31T00:00:00      1
# Name: reported_date, Length: 3829, dtype: int64
#
# reported_time:
# 03:09:00.0000000    52
# 02:56:00.0000000    52
# 17:00:00.0000000    51
# 19:18:00.0000000    51
# 03:13:00.0000000    51
#                     ..
# 02:46:38.0000000     1
# 01:32:01.0000000     1
# 00:24:42.0000000     1
# 19:58:57.0000000     1
# 05:15:37.0000000     1
# Name: reported_time, Length: 26254, dtype: int64
#
# initial_call_type:
# Unknown                                               13602
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW             5348
# SUSPICIOUS PERSON, VEHICLE, OR INCIDENT                4512
# DISTURBANCE                                            3305
# ASLT - CRITICAL (NO SHOOTINGS)                         2816
#                                                       ...
# ASSIGNED DUTY - STAKEOUT                                  1
# INFORMATIONAL BROADCASTS                                  1
# ANIMAL - DANGEROUS                                        1
# HARBOR - WATER EMERGENCIES                                1
# OBS - UNKNOWN - ANI/ALI - PAY PHN (INCL OPEN LINE)        1
# Name: initial_call_type, Length: 186, dtype: int64
#
# final_call_type:
# Unknown                                   13602
# SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON     6167
# PROWLER - TRESPASS                         4572
# DISTURBANCE - OTHER                        3893
# ASSAULTS, OTHER                            3236
#                                           ...
# DOWN TIME - OUT OF SERVICE                    1
# ESCAPE - PRISONER                             1
# FIGHT - PHYSICAL (NO WEAPONS)                 1
# ASLT - DV CRITICAL                            1
# OBS - PROWLER                                 1
# Name: final_call_type, Length: 203, dtype: int64
#
# call_type:
# 911                              30545
# ONVIEW                           15702
# Unknown                          13602
# TELEPHONE OTHER, NOT 911          4316
# ALARM CALL (NOT POLICE ALARM)      540
# TEXT MESSAGE                        30
# HISTORY CALL (RETRO)                 1
# SCHEDULED EVENT (RECURRING)          1
# Name: call_type, dtype: int64
#
# officer_squad:
# TRAINING - FIELD TRAINING SQUAD                 6998
# WEST PCT 1ST W - DAVID - PLATOON 1              1706
# WEST PCT 3RD W - KING - PLATOON 1               1592
# WEST PCT 1ST W - KING - PLATOON 1               1377
# SOUTHWEST PCT 2ND W - FRANK - PLATOON 2         1302
#                                                 ...
# RECORDS - DAY SHIFT                                1
# TRAINING - LEARNING MANAGEMENT SYSTEM              1
# HOMICIDE SQUAD A                                   1
# NORTH PCT 3RD W - LINCOLN                          1
# COMMUNITY OUTREACH - SPECIAL PROJECTS DETAIL       1
# Name: officer_squad, Length: 277, dtype: int64
#
# arrest_flag:
# N    57400
# Y     7337
# Name: arrest_flag, dtype: int64
#
# frisk_flag:
# N          48527
# Y          15732
# Unknown      478
# Name: frisk_flag, dtype: int64
#
# precinct:
# West         18416
# North        13464
# Unknown      11044
# East          8871
# South         7833
# Southwest     4989
# OOJ            120
# Name: precinct, dtype: int64
#
# sector:
# Unknown    10973
# K           6495
# M           5539
# E           4677
# N           3850
# D           3644
# R           3029
# F           2974
# B           2847
# Q           2734
# L           2605
# O           2442
# S           2363
# U           2361
# G           2291
# W           2010
# C           1901
# J           1799
# 99           138
# OOJ           65
# Name: sector, dtype: int64
#
# beat:
# Unknown    10967
# K3          3901
# M3          2756
# N3          1944
# E2          1942
# E1          1581
# R2          1455
# D1          1452
# N2          1440
# K2          1433
# M2          1403
# M1          1383
# D2          1342
# Q3          1309
# F2          1237
# K1          1161
# E3          1152
# B2          1085
# U2          1074
# B1          1060
# O1           984
# S2           918
# L2           905
# F3           877
# F1           860
# L1           852
# D3           850
# L3           848
# G2           847
# W2           846
# R1           846
# U1           809
# Q2           794
# S3           786
# G3           782
# C1           777
# O3           775
# R3           728
# B3           707
# J3           688
# W1           684
# O2           683
# G1           660
# C3           659
# S1           659
# J1           654
# Q1           631
# W3           481
# U3           478
# C2           466
# N1           464
# J2           457
# 99           139
# OOJ           64
# S              2
# Name: beat, dtype: int64

# %%
import pandas as pd

def clean_reported_time(df1, time_col="reported_time"):
    """
    Cleans a reported_time column by:
    1. Stripping spaces
    2. Replacing dash or invalid placeholders with NaN
    3. Converting to datetime
    4. Removing microseconds (floor to seconds)
    5. Keeping only the time component
    """
    # Replace dash-like missing values with NaN
    df1[time_col] = df1[time_col].replace(["-", "", " "], pd.NA)
    
    # Strip leading/trailing spaces
    df1[time_col] = df1[time_col].astype(str).str.strip()
    
    # Convert to datetime, coerce errors to NaT
    df1[time_col] = pd.to_datetime(df1[time_col], format="%H:%M:%S.%f", errors="coerce")
    
    # Remove microseconds (round down to nearest second)
    df1[time_col] = df1[time_col].dt.floor("S")
    
    # Keep only the time component
    df1[time_col] = df1[time_col].dt.time
    
    return df1

# Usage
df1 = clean_reported_time(df1)

# %%
#check for null values
df1.isna().sum()
# Out:
# subject_age_group             0
# subject_id                    0
# go_/_sc_num                   0
# terry_stop_id                 0
# stop_resolution               0
# weapon_type                   0
# officer_id                    0
# officer_yob                   0
# officer_gender                0
# officer_race                  0
# subject_perceived_race        0
# subject_perceived_gender      0
# reported_date                 0
# reported_time                 0
# initial_call_type             0
# final_call_type               0
# call_type                     0
# officer_squad               569
# arrest_flag                   0
# frisk_flag                    0
# precinct                      0
# sector                        0
# beat                          0
# dtype: int64

# %%
# Show rows where officer_squad is null
df1[df1["officer_squad"].isna()]
# Out:
#       subject_age_group   subject_id     go_/_sc_num  terry_stop_id  \
# 142             26 - 35           -1  20150000111374          33538
# 336             36 - 45           -1  20160000000012         114952
# 370             46 - 55   7743686531  20190000354957    10396648540
# 388             46 - 55           -1  20190000120272         548421
# 432             36 - 45   8597903457  20190000243853     8597867579
# ...                 ...          ...             ...            ...
# 63557           26 - 35  21514169827  20210000049063    21514152257
# 63826           36 - 45   7734473862  20230000361937    53439369124
# 63928            1 - 17           -1  20150000147414          41108
# 64318           46 - 55   9638620853  20200000326941    17954968854
# 64686           36 - 45           -1  20150000148740          55919
#
#       stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 142    Offense Report        None       7521         1986         Female
# 336     Field Contact        None         -9         1900  Non-Specified
# 370     Field Contact     Unknown    Unknown         1900  Non-Specified
# 388    Offense Report        None       8328         1985           Male
# 432     Field Contact     Unknown       5469         1967           Male
# ...               ...         ...        ...          ...            ...
# 63557   Field Contact     Unknown       X647         1956           Male
# 63826   Field Contact     Unknown       7932         1991           Male
# 63928  Offense Report        None       7745         1988         Female
# 64318   Field Contact     Unknown       7722         1989           Male
# 64686   Field Contact        None       7712         1987           Male
#
#       officer_race  ...                                 initial_call_type  \
# 142          White  ...                         DISTURBANCE - DV CRITICAL
# 336        Unknown  ...                                           Unknown
# 370        Unknown  ...                                           Unknown
# 388          White  ...             UNKNOWN - COMPLAINT OF UNKNOWN NATURE
# 432          White  ...                                          TRESPASS
# ...            ...  ...                                               ...
# 63557        White  ...                                           Unknown
# 63826        White  ...  NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)
# 63928      Unknown  ...                                ASLT - DV CRITICAL
# 64318        White  ...                                         FOLLOW UP
# 64686        White  ...          OBS - FIGHT - IP - PHYSICAL (NO WEAPONS)
#
#                                final_call_type                 call_type  \
# 142    DV - ARGUMENTS, DISTURBANCE (NO ARREST)                       911
# 336                                    Unknown                   Unknown
# 370                                    Unknown                   Unknown
# 388    DV - ARGUMENTS, DISTURBANCE (NO ARREST)                    ONVIEW
# 432     SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON                    ONVIEW
# ...                                        ...                       ...
# 63557                                  Unknown                   Unknown
# 63826                        NARCOTICS - OTHER                    ONVIEW
# 63928                          ASSAULTS, OTHER                       911
# 64318   SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON                    ONVIEW
# 64686                      DISTURBANCE - OTHER  TELEPHONE OTHER, NOT 911
#
#       officer_squad arrest_flag frisk_flag precinct   sector     beat  year
# 142             NaN           N          N     east        G       G2  2015
# 336             NaN           N          N    north        N       N3  2016
# 370             NaN           N          N     east        E       E3  2019
# 388             NaN           N          N     east        E       E2  2019
# 432             NaN           N          N  unknown  Unknown  Unknown  2019
# ...             ...         ...        ...      ...      ...      ...   ...
# 63557           NaN           N          N  unknown  Unknown  Unknown  2021
# 63826           NaN           N          N     west        M       M3  2023
# 63928           NaN           N          N     east        G       G2  2015
# 64318           NaN           N          Y     west        K       K3  2020
# 64686           NaN           N          Y     west        K       K3  2015
#
# [569 rows x 24 columns]

# %%
df1[(df1["subject_id"] == -1) & (df1["weapon_type"] == "None")]
# Out:
#       subject_age_group  subject_id     go_/_sc_num  terry_stop_id  \
# 0               26 - 35          -1  20170000036835         234548
# 1               46 - 55          -1  20180000275629         481899
# 4               18 - 25          -1  20150000002928          54115
# 5               18 - 25          -1  20160000273397         180515
# 6               Unknown          -1  20160000465080         224398
# ...                 ...         ...             ...            ...
# 64732           18 - 25          -1  20170000325937         354197
# 64733           26 - 35          -1  20190000122094         549491
# 64734           36 - 45          -1  20180000467077         512455
# 64735           26 - 35          -1  20190000059044         532813
# 64736           18 - 25          -1  20180000001424         412377
#
#       stop_resolution weapon_type officer_id  officer_yob officer_gender  \
# 0      Offense Report        None       4852         1953           Male
# 1       Field Contact        None       8544         1993         Female
# 4       Field Contact        None       7745         1988         Female
# 5      Offense Report        None       6968         1981           Male
# 6      Offense Report        None       7700         1990           Male
# ...               ...         ...        ...          ...            ...
# 64732  Offense Report        None       7755         1971           Male
# 64733          Arrest        None       7489         1985         Female
# 64734          Arrest        None       7758         1987           Male
# 64735  Offense Report        None       7649         1986           Male
# 64736   Field Contact        None       8558         1993           Male
#
#       officer_race  ...     reported_time  \
# 0            Asian  ...  18:36:00.0000000
# 1         Hispanic  ...  13:47:00.0000000
# 4          Unknown  ...  00:22:00.0000000
# 5            White  ...  14:05:00.0000000
# 6            White  ...  19:16:00.0000000
# ...            ...  ...               ...
# 64732        White  ...  22:58:00.0000000
# 64733        White  ...  13:01:00.0000000
# 64734        White  ...  04:35:00.0000000
# 64735        White  ...  14:35:00.0000000
# 64736        White  ...  14:10:00.0000000
#
#                                        initial_call_type  \
# 0                                            DISTURBANCE
# 1                                                Unknown
# 4                                                Unknown
# 5                                            DISTURBANCE
# 6      OBS WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/D...
# ...                                                  ...
# 64732                                            Unknown
# 64733         SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 64734  OBS - BURG - IP/JO - COMM BURG (INCLUDES SCHOOLS)
# 64735                     ASLT - CRITICAL (NO SHOOTINGS)
# 64736                                            Unknown
#
#                       final_call_type call_type  \
# 0                    THEFT - SHOPLIFT       911
# 1                             Unknown   Unknown
# 4                             Unknown   Unknown
# 5                 DISTURBANCE - OTHER       911
# 6      WARRANT SERVICES - MISDEMEANOR       911
# ...                               ...       ...
# 64732                         Unknown   Unknown
# 64733       WARRANT SERVICES - FELONY    ONVIEW
# 64734         NARCOTICS - NARS REPORT       911
# 64735                 ASSAULTS, OTHER       911
# 64736                         Unknown   Unknown
#
#                                  officer_squad arrest_flag frisk_flag  \
# 0        NORTH PCT 2ND W - LINCOLN - PLATOON 1           N          N
# 1             NORTH PCT 2ND WATCH - B/N RELIEF           N          N
# 4            SOUTH PCT 3RD W - SAM - PLATOON 2           N          N
# 5      SOUTHWEST PCT 2ND W - FRANK - PLATOON 2           N          Y
# 6         SOUTH PCT 2ND W - ROBERT - PLATOON 2           N          Y
# ...                                        ...         ...        ...
# 64732        WEST PCT 3RD W - KING - PLATOON 1           N          N
# 64733                  NORTH PCT OPS - ACT DAY           N          N
# 64734    EAST PCT 1ST W - E/G RELIEF (CHARLIE)           N          N
# 64735             SOUTH PCT 2ND W - R/S RELIEF           N          N
# 64736          TRAINING - FIELD TRAINING SQUAD           N          N
#
#         precinct   sector     beat
# 0          North        L       L3
# 1           West        Q       Q2
# 4        Unknown  Unknown  Unknown
# 5      Southwest        F       F1
# 6          South        R       R2
# ...          ...      ...      ...
# 64732       West        M       M2
# 64733      North        N       N3
# 64734       East        E       E1
# 64735      South        S       S1
# 64736    Unknown  Unknown  Unknown
#
# [32566 rows x 23 columns]

# %%
df1[(df1["subject_id"] == -1) & ~(df1["weapon_type"] == "None")]
# Out:
#       subject_age_group  subject_id     go_/_sc_num  terry_stop_id  \
# 15              26 - 35          -1  20170000064956         241073
# 24              26 - 35          -1  20190000114043         546950
# 28              36 - 45          -1  20180000419918         500809
# 35              Unknown          -1  20210000064922    21923094829
# 49              18 - 25          -1  20170000190550         269774
# ...                 ...         ...             ...            ...
# 64675           26 - 35          -1  20170000323532         303776
# 64685           26 - 35          -1  20190000000889         538130
# 64702           Unknown          -1  20250000133817    64032315733
# 64713           26 - 35          -1  20190000048136         530293
# 64719           18 - 25          -1  20180000196947         425872
#
#                 stop_resolution                        weapon_type officer_id  \
# 15                       Arrest  Knife/Cutting/Stabbing Instrument       7634
# 24                       Arrest  Knife/Cutting/Stabbing Instrument       7575
# 28               Offense Report  Knife/Cutting/Stabbing Instrument       5489
# 35                Field Contact                            Unknown       8788
# 49                       Arrest                            Handgun       7761
# ...                         ...                                ...        ...
# 64675  Referred for Prosecution  Knife/Cutting/Stabbing Instrument       8426
# 64685             Field Contact  Knife/Cutting/Stabbing Instrument       7793
# 64702            Offense Report                            Unknown       9020
# 64713                    Arrest  Knife/Cutting/Stabbing Instrument       5360
# 64719                    Arrest  Knife/Cutting/Stabbing Instrument       8460
#
#        officer_yob officer_gender officer_race  ...     reported_time  \
# 15            1977           Male        White  ...  12:56:00.0000000
# 24            1985           Male        White  ...  15:37:00.0000000
# 28            1964           Male        White  ...  02:20:00.0000000
# 35            1986           Male      Unknown  ...  03:17:49.0000000
# 49            1986           Male        White  ...  06:17:00.0000000
# ...            ...            ...          ...  ...               ...
# 64675         1987           Male        White  ...  19:31:00.0000000
# 64685         1986           Male        White  ...  16:53:00.0000000
# 64702         1900           Male      Unknown  ...  11:12:50.0000000
# 64713         1966           Male        Asian  ...  23:56:00.0000000
# 64719         1986           Male        Asian  ...  02:24:00.0000000
#
#                                        initial_call_type  \
# 15               SUSPICIOUS PERSON, VEHICLE, OR INCIDENT
# 24                             DISTURBANCE - DV CRITICAL
# 28        UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)
# 35                         ASLT - PERSON SHOT OR SHOT AT
# 49     OBS WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/D...
# ...                                                  ...
# 64675                 OBS - DOWN - CHECK FOR PERSON DOWN
# 64685                                            Unknown
# 64702                                 ASLT - DV CRITICAL
# 64713  OBS WEAPN-IP/JO-GUN,DEADLY WPN (NO THRT/ASLT/D...
# 64719        BURG - RESD (INCL UNOCC STRUCTURES ON PROP)
#
#                                   final_call_type call_type  \
# 15                      WARRANT SERVICES - FELONY       911
# 24     DV - DOMESTIC VIOL/ASLT (ARREST MANDATORY)       911
# 28                     CRISIS COMPLAINT - GENERAL       911
# 35            AUTOMOBILES - AUTO THEFT & RECOVERY       911
# 49                      WEAPON, PERSON WITH - GUN       911
# ...                                           ...       ...
# 64675           WEAPON,PERSON WITH - OTHER WEAPON       911
# 64685                                     Unknown   Unknown
# 64702     DV - ARGUMENTS, DISTURBANCE (NO ARREST)       911
# 64713           WEAPON,PERSON WITH - OTHER WEAPON       911
# 64719          BURGLARY - RESIDENTIAL, UNOCCUPIED       911
#
#                                  officer_squad arrest_flag frisk_flag  \
# 15          WEST PCT 1ST W - DAVID - PLATOON 1           N          Y
# 24                 WEST PCT 2ND W - D/M RELIEF           N          Y
# 28                NORTH PCT 3RD W - B/N RELIEF           N          Y
# 35             TRAINING - FIELD TRAINING SQUAD           N          N
# 49       EAST PCT 1ST W - E/G RELIEF (CHARLIE)           N          Y
# ...                                        ...         ...        ...
# 64675         NORTH PCT 2ND WATCH - B/N RELIEF           N          N
# 64685  SOUTHWEST PCT 2ND W - FRANK - PLATOON 2           N          Y
# 64702          TRAINING - FIELD TRAINING SQUAD           N          N
# 64713              WEST PCT 3RD W - K/Q RELIEF           N          Y
# 64719       WEST PCT 3RD W - QUEEN - PLATOON 1           N          N
#
#         precinct   sector     beat
# 15          West        K       K2
# 24          West        D       D3
# 28         North        B       B1
# 35     Southwest        F       F1
# 49          East        G       G3
# ...          ...      ...      ...
# 64675      North        N       N3
# 64685    Unknown  Unknown  Unknown
# 64702       West        K       K3
# 64713       West        M       M2
# 64719       West        Q       Q2
#
# [2655 rows x 23 columns]

# %%
# Convert officer_squad and precinct to lowercase
df1["officer_squad"] = df1["officer_squad"].str.lower()
df1["precinct"] = df1["precinct"].str.lower()

# Extract the first word from officer_squad
first_word = df1["officer_squad"].str.split().str[0]

# Compare with precinct and count matches
match_count = (first_word == df1["precinct"]).sum()

print("Number of matching rows:", match_count)
# Out:
# Number of matching rows: 42403

# %%
df1["year"] = df1["go_/_sc_num"].astype(str).str[:4]
df1.head()
# Out:
#   subject_age_group   subject_id     go_/_sc_num  terry_stop_id  \
# 0           26 - 35           -1  20170000036835         234548
# 1           46 - 55           -1  20180000275629         481899
# 2           36 - 45  49326761681  20230000118635    49327076666
# 3           36 - 45  53986235598  20240000029589    53986202139
# 4           18 - 25           -1  20150000002928          54115
#
#   stop_resolution                        weapon_type officer_id  officer_yob  \
# 0  Offense Report                               None       4852         1953
# 1   Field Contact                               None       8544         1993
# 2   Field Contact  Knife/Cutting/Stabbing Instrument       7766         1984
# 3   Field Contact                            Unknown       8723         1994
# 4   Field Contact                               None       7745         1988
#
#   officer_gender officer_race  ...  \
# 0           Male        Asian  ...
# 1         Female     Hispanic  ...
# 2           Male        White  ...
# 3           Male        White  ...
# 4         Female      Unknown  ...
#
#                             initial_call_type  \
# 0                                 DISTURBANCE
# 1                                     Unknown
# 2          OBS - DOWN - CHECK FOR PERSON DOWN
# 3  SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 4                                     Unknown
#
#                           final_call_type call_type  \
# 0                        THEFT - SHOPLIFT       911
# 1                                 Unknown   Unknown
# 2  SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON    ONVIEW
# 3                     DISTURBANCE - OTHER    ONVIEW
# 4                                 Unknown   Unknown
#
#                                 officer_squad arrest_flag frisk_flag precinct  \
# 0       north pct 2nd w - lincoln - platoon 1           N          N    north
# 1            north pct 2nd watch - b/n relief           N          N     west
# 2  west pct 1st w - queen (david) - platoon 1           N          Y     west
# 3           west pct 3rd w - king - platoon 1           N          N     west
# 4           south pct 3rd w - sam - platoon 2           N          N  unknown
#
#     sector     beat  year
# 0        L       L3  2017
# 1        Q       Q2  2018
# 2        K       K3  2023
# 3        D       D2  2024
# 4  Unknown  Unknown  2015
#
# [5 rows x 24 columns]
